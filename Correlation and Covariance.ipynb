# %% [markdown]
# #Correlation and Covariance
#
# 1. Define Covariance and explain how it differs from Correlation in terms of scale and interpretation.
#
#  > Covariance is a statistical measure that indicates the direction of the linear relationship between two variables. It shows whether the variables move together (positive) or in opposite directions (negative).
#
#  if one increase the other also increse is called positive covariance
#
#  if one increses the other decreases is called negative covarinance
#
#  when there is no relationship it is called zero covarinace
#
#  scale: Covariance depends on the units of the variables, whereas correlation is unit free and standardized.
#
#  Interpretation: Covariance only indicates the direction of relationship, but correlation indicates both direction and strength of the relationship.
#
# 2. What does a positive, negative, and zero covariance indicate about the relationship between two variables?
#
#  > Positive covariance:
#
#    It indicates two variable are moving in the same direction. if one increases the other also increases(positive), respectively when decreasing(negative) also.
#
#    negative covariance:
#
#    when two variables moves in opposite direction,means when one decreses the other increase, respectively when decreasing also.this is called negative covariance.
#
#    zero covariance:
#
#    there will be no linear relationship. Means not connected each other. an change will not be effecting each other.
#
# 3. Discuss the limitations of covariance as a measure of relationship between two variables. Why is correlation
# preferred in many cases?
#
#  > Limitations of Covariance:
#
#    - It is affected by the variable's measurement units. a simple change in scale can effect covariance value.leads to difficulty.
#
#    - No fixed range or no  standardized range means so it will be hard to judge the strength of relationship.
#
#    - it only shows the relationship direction(positive or negative). not how strong it is.
#
#    - Not easy to interpret because it don't shows how strong the relationship is.
#
#    **Why Correlation is Preferred**
#
#    its is because correlation is unit free and has standardized measurement. it don't get effected by the units of variables.  it has a range between -1 & +1, make the interpretation easier.it also indicates both strength and direction of the relationship between variables.
#
#    **since it is standardized, it allows for easy comparison across different datasets, making it more practical and widely used.**
#
#
# 4. Explain the difference between Pearson’s correlation coefficient and Spearman’s rank correlation
# coefficient. When would you prefer use Spearman’s correlation?
#
#  > Pearson’s Correlation Coefficient:
#
#    In this method it measures the strength and direction of linear relationship between two continuous variables. using the actual numerical value of the data, assuming the data are normally distributed.
#
#    Spearman’s rank correlation coefficient:
#
#    in this method the data is converted into ranks instead of their actual value. Thus it measure the strength and direction by using the rank of two variables
#
#    Spearman’s correlation is preferred when:
#
#    - The data are ordinal or ranked.
#
#    - when relationship is not linear but monotonic
#
#    - when data doesnt follow normal distribution
#
#    - There are outliers that may affect Pearson’s correlation.
#
# 5. If the correlation coefficient between two variables X and Y is 0.85, interpret this value in context. Can you
# infer causation from this value? Why or why not?
#
#  > A value of 0.85 in correlation coefficient indicates a strong positive relationship, meaning X & Y increase together
#
#    However, causation cannot be inferred because correlation only indicates association, not cause and effect, and other factors may influence the relationship.
#
# 6. If the correlation coefficient between two variables X and Y is 0.85, interpret this value in context. Can you
# infer causation from this value? Why or why not?
#
#  > given data,
#
#    X= 2, 4, 6, 8
#
#    Y= 3, 7, 5, 10
#
#    find the mean,
#
#    X= 2+4+6+8/4 = 5
#
#    Y= 3+7+5+10/4 = 6.25
#
#    using covariance formula:
#
#    | X | Y | X - 5 | Y - 6.25 | Product |
# |---|---|-------|----------|---------|
# | 2 | 3 | -3    | -3.25    | 9.75    |
# | 4 | 7 | -1    | 0.75     | -0.75   |
# | 6 | 5 | 1     | -1.25    | -1.25   |
# | 8 | 10| 3     | 3.75     | 11.25   |
#
#
#   sum of product= 19
#
#   Cov(X,Y)= 19\4-1 = 19/3
#
#   **Cov(X,Y)= 6.33**
#
#   since it is a positive value x and y has relationship and it moves together.
#
# 7. Compute the Pearson correlation coefficient between variables A and B:
#
#  > $$
# r = \frac{\sum (A_i - \bar{A})(B_i - \bar{B})}{\sqrt{\sum (A_i - \bar{A})^2 \cdot \sum (B_i - \bar{B})^2}}
# $$
#
#  mean(A)= 30
#
#  mean(B)= 18.4
#
#  | A  | B  | A-30 | B-18.4 | (A-30)(B-18.4) | (A-30)^2 | (B-18.4)^2 |
# |----|----|------|--------|----------------|----------|------------|
# | 10 | 8  | -20  | -10.4  | 208            | 400      | 108.16     |
# | 20 | 14 | -10  | -4.4   | 44             | 100      | 19.36      |
# | 30 | 18 | 0    | -0.4   | 0              | 0        | 0.16       |
# | 40 | 24 | 10   | 5.6    | 56             | 100      | 31.36      |
# | 50 | 28 | 20   | 9.6    | 192            | 400      | 92.16      |
#
# $$
# \sum (A - \bar{A})(B - \bar{B}) = 500
# $$
#
# $$
# \sum (A - \bar{A})^2 = 1000
# $$
#
# $$
# \sum (B - \bar{B})^2 = 251.2
# $$
#
# r= 500/√1000x251.2
#
# = 500/√251200
#
# = 500/501.2
#
# = 0.998
#
# **r= 0.998 show a very strong and positive linear  relationship between A and b**
#
# 8.  The following table shows heights (in cm) and weights (in kg) of 5 students.
# Find the correlation coefficient between Height and Weight.
#
#  > Given data,
#
#    Height (X) = 150, 160, 165, 170, 180
#
#    Weight (Y) = 50, 55, 58, 62, 70
#
#    mean(x)= 165
#
#    mean(y)= 59
#
#    | X (Height) | Y (Weight) | X-165 | Y-59 | (X-165)(Y-59) | (X-165)^2 | (Y-59)^2 |
# |------------|------------|-------|------|---------------|-----------|-----------|
# | 150        | 50         | -15   | -9   | 135           | 225       | 81        |
# | 160        | 55         | -5    | -4   | 20            | 25        | 16        |
# | 165        | 58         | 0     | -1   | 0             | 0         | 1         |
# | 170        | 62         | 5     | 3    | 15            | 25        | 9         |
# | 180        | 70         | 15    | 11   | 165           | 225       | 121       |
#
# $$
# \sum (X - \bar{X})(Y - \bar{Y}) = 335
# $$
#
# $$
# \sum (X - \bar{X})^2 = 500
# $$
#
# $$
# \sum (Y - \bar{Y})^2 = 228
# $$
#
# r= √335/√500x228
#
# = 335/√11400
#
# √114000 = 337.64
#
# r= 335/337.64
#
# = 0.992
#
# **r= 0.992, show very positive correlation between height and weight**
#
# 9.  The following table shows heights (in cm) and weights (in kg) of 5 students.
# Find the correlation coefficient between Height and Weight
#
#  > As X increases(1->5) and Y decreases(15->3)
#
#  **it shows the variables move in opposite direction means there is a negative relation between X and Y.**
#
# 10. Two investment portfolios have the following returns (%) over 5 years. Compute the covariance and
# correlation coefficient, and interpret whether the portfolios move together.
#
#  > Given data,
#
#    Portfolio A = 8, 10, 12, 9, 11
#
#    Portfolio B = 6, 9, 11, 8, 10
#
#    mean(A)= 50/5 =50
#
#    mean(B)= 44/5 =4.8
#
#    | A | B | A-10 | B-8.8 | (A-10)(B-8.8) |
# |---|---|------|-------|---------------|
# | 8 | 6 | -2   | -2.8  | 5.6           |
# |10 | 9 | 0    | 0.2   | 0             |
# |12 |11 | 2    | 2.2   | 4.4           |
# | 9 | 8 | -1   | -0.8  | 0.8           |
# |11 |10 | 1    | 1.2   | 1.2           |
#
# $$
# \sum (A - \bar{A})(B - \bar{B}) = 12
# $$
#
# covariance=
#
# cov(A,B)= 12/5-1
#
# = 12/4
#
# = 3
#
# Correlation=
#
# r= 12/√10x14.8
#
#  = 12/√148
#
#  = 12/12.17
#
#  = 0.986
#
#  **covariance= 3**
#
#  **correlation= 0.986**
#
#  **There is a strong positive correlation, meaning both portfolios move together in the same direction.**
